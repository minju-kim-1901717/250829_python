# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter33 ~ 41 수업은 잘 들으셨나요?
#
# Chapter33 ~ 41의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제 1]
#
# 사용자로부터 두 개의 숫자를 입력받아 나눗셈을 수행하는 프로그램을 작성하세요.
#
# [예외처리]
# - 입력 값이 숫자가 아닐 때 발생할 수 있는 ValueError
# - 나누는 수가 0일 때 발생할 수 있는 ZeroDivisionError
# - 위 2가지 예외처리 후 사용자에게 이해하기 쉬운 메시지 작성 후 출력되도록 코드를 작성

# %%
try:
    x,y = map(int, input("두개의 숫자를 입력해주세요 \n").split(" "))
    print(f"두 숫자를 나누면 {x} / {y} = {x/y}")

#입력 값이 숫자가 아닐 때 발생할 수 있는 ValueError
except ValueError:
    print("정수가 아니므로 나눌 수없습니다")

# 나누는 수가 0일 때 발생할 수 있는 ZeroDivisionError
except ZeroDivisionError:
    print("나누는 숫자가 0이므로 나눌 수 없습니다")
# Out:
# 두개의 숫자를 입력해주세요
# 3 0
# 나누는 숫자가 0이므로 나눌 수 없습니다

# %% [markdown]
# ---

# %% [markdown]
# [문제 2]
#
# 파일을 읽어서 내용을 출력하는 프로그램을 작성하세요.
#
# - 파일이 존재하지 않을 때 발생하는 FileNotFoundError를 처리
# - 파일이 존재하지 않을 경우 "파일을 찾을 수 없습니다."라는 메시지를 출력

# %%
try:
    read_file = open("test.txt", "r")
    print(read_file.read())
except FileNotFoundError:
    print("파일을 찾을 수 없습니다.")
# Out:
# 파일을 찾을 수 없습니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제 3]
#
# 사용자로부터 여러 개의 숫자를 입력받아 리스트에 저장한 후, 사용자가 'done'이라고 입력할 때까지 계속 입력받으세요.
#
# - 입력 중 숫자가 아닌 값이 입력되면 ValueError를 처리
# - 숫자 외 값이 입력된 경우 어떤 값이 잘못 입력되었는지 사용자에게 알려주는 문구 출력<br>
#   (예: f"잘못된 값: {변수}. 숫자를 입력해주세요.")

# %%
number = []

while True:
    x = input("숫자를 입력해주세요 (종료: done): ")

    #done 입력시 종료
    if x == "done":
        break
    2
        x = int(x)           # 숫자로 변환
        number.append(x)     # 리스트에 추가
        print("추가되었습니다")
    except ValueError:
        print(f"잘못된 값{x}, 숫자를 입력해주세요.")

print("최종 리스트:", number)
# Out:
# 숫자를 입력해주세요 (종료: done): 1
# 추가되었습니다
# 숫자를 입력해주세요 (종료: done):
# 잘못된 값, 숫자를 입력해주세요.
# 숫자를 입력해주세요 (종료: done): 3
# 추가되었습니다
# 숫자를 입력해주세요 (종료: done): ab
# 잘못된 값ab, 숫자를 입력해주세요.
# 숫자를 입력해주세요 (종료: done): done
# 최종 리스트: [1, 3]

# %% [markdown]
# ---

# %% [markdown]
# [문제 4]
#
# 사용자 정의 예외 NegativeNumberError를 생성하고, 사용자로부터 숫자를 입력받아 음수일 경우 NegativeNumberError를 발생시키는 프로그램을 작성하세요.
#
# - 예외 처리 구문을 사용하여 음수 입력 시 "양수를 입력해주세요."라는 메시지를 출력

# %%
class NegativeNumberError(Exception):
    pass

try:
    a = int(input("숫자를 입력해주세요"))
    if a < 0 :
        raise NegativeNumberError
    else:
        print(f"입력되었습니다 {a}")

except NegativeNumberError:
    print("양수를 입력해주세요")
# Out:
# 숫자를 입력해주세요-5
# 양수를 입력해주세요

# %% [markdown]
# ---

# %% [markdown]
# [문제 5]
#
# datetime 모듈을 사용하여 현재 날짜와 시간을 출력하는 프로그램을 작성하세요.
#
# 또한, 사용자로부터 태어난 년도를 입력받아 현재 나이를 계산하여 출력하세요.

# %%
import datetime

today = datetime.datetime.now()
print(today)

age = int(input(f"태어난 년도를 입력해주세요"))
print(f"당신의 나이는 {today.year - age + 1}살 입니다") # +1의 경우 한국나이 계산, +1이 없을경우 만나이계산
# Out:
# 2025-08-29 08:36:25.058253
# 태어난 년도를 입력해주세요2003
# 현재 나이는 23살 입니다

# %% [markdown]
# ---

# %% [markdown]
# [문제 6]
#
# requests 모듈을 사용하여, 웹 페이지의 HTML을 가져오는 간단한 웹 스크레이퍼를 작성하세요.
#
# 'https://kream.co.kr/'에서<br>
# 데이터를 가져와서 상태 코드와 HTML의 첫 100자를 출력하세요.<br>
# (실습 전 requests 모듈을 설치해야 함)

# %%
# !pip -q install requests

# %%
import requests

url = "https://kream.co.kr/"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

try:
    resp = requests.get(url, headers=headers, timeout=30)
    print("Status code:", resp.status_code)
    # 인코딩 보정 (가끔 None일 수 있어요)
    resp.encoding = resp.apparent_encoding or resp.encoding
    print(resp.text[:100])
except requests.exceptions.RequestException as e:
    print("요청 중 오류:", e)
# Out:
# Status code: 500
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta name="robots" content="noindex, nofollow" />
# <meta htt

# %% [markdown]
# ---

# %% [markdown]
# [문제 7]
#
# 함수 실행 시간을 측정하는 데코레이터 timer_decorator를 작성하세요.
#
# 임의의 함수가 실행되는 시간을 측정하여 "함수 실행 시간: x.xx초" 형태로 출력하세요.

# %%
import time

def timer_decorator(func):
    def wrapper(*args, **kwargs):
        start = time.perf_counter()
        result = func(*args, **kwargs)
        print(f"함수 실행 시간: {time.perf_counter() - start:.2f}초")
        return result
    return wrapper

#임의의 함수에 time.sleep을 넣어 timer_decorator가 잘 돌아가는지 확인 가능
@timer_decorator
def my_time():
    time.sleep(2)
    print("함수가 실행되었습니다.")

my_time()
# Out:
# 함수가 실행되었습니다.
# 함수 실행 시간: 2.00초

# %% [markdown]
# ---

# %% [markdown]
# [문제 8]
#
# 여러분이 자주 사용하는 수학적 연산<br>
# (예: 삼각형 넓이, 원의 넓이, 직육면체의 넓이)을 수행하는 함수들을 포함하는 mymath.py라는 이름의 모듈을 만드세요.
#
# 이 모듈을 사용하여 작성된 함수들을 실제로 임포트하고 사용하는 간단한 프로그램을 작성하세요.

# %%
#mymath.py

pi = 3.141592

def number_input():
    values = int(input("반지름을 입력해주세요"))
    return values

# 원의 넓이
def circle(radius):
    return pi * radius * radius

#정삼각형의 넓이
def triangle(radius):
    return 0.5 * radius * radius

# 정사각형의 넓이
def square(radius):
    return radius * radius

# %%
#math

import mymath as math

radius = math.number_input()

print(f"원의 넓이: {math.circle(radius)}")
print(f"정삼각형의 넓이: {math.triangle(radius)}")
print(f"정사각형의 넓이: {math.square(radius)}")

# %% [markdown]
# vscode 실행화면
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# [문제 9]
#
# animals라는 패키지를 만들고, 이 패키지 내에 mammals, birds라는 두 개의 서브 모듈을 생성하세요.
#
# - 각 모듈에는 최소한 한 개 이상의 동물에 관한 클래스를 정의하세요<br>
#   (예: mammals에는 Dog, birds에는 Eagle)
# - 이 패키지와 모듈을 사용하여 동물들의 정보를 출력하는 프로그램을 작성
#
# 폴더 및 파일 구조
# ```
# animals/(폴더)
# ├── __init__.py
# ├── mammals.py
# └── birds.py
# ```

# %%
#birds.py

bird_1 = "Eagle"
bird_2 = "Sparrow"
bird_3 = "Penguin"

# %%
#mammals.py

mammals_1 = "Dog"
mammals_2 = "Lion"
mammals_3 = "Dolpin"

# %%
import animals.birds as one
import animals.mammals as two

print("🦅" *10)
print(one.bird_1)
print(one.bird_2)
print(one.bird_3)
print("🐕"*10)
print(two.mammals_1)
print(two.mammals_2)
print(two.mammals_3)
# Out:
# 🦅🦅🦅🦅🦅🦅🦅🦅🦅🦅
# Eagle
# Sparrow
# Penguin
# 🐕🐕🐕🐕🐕🐕🐕🐕🐕🐕
# Dog
# Lion
# Dolpin

# %% [markdown]
# ---
